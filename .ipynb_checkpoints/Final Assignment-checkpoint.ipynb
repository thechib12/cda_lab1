# %% [markdown]
# # Lab Assignment 1: Cyber Data Analytics
# ### Ruben Groot Roessink & Christiaan van der Bogaard

# %% [markdown]
# This Jupyter Notebook is used to process credit card data from Adjen. It is part of the first lab assignment of the course Cyber Data Analytics of the 4TU Master Cyber Security of TU Delft and Univerity of Twente.
#
# For questions you can email to Ruben Groot Roessink (r.grootroessink@student.utwente.nl) or Christiaan van der Bogaard (c.h.m.vanderbogaard@student.utwente.nl)

# %% [markdown]
# #### Imports + General data structuring

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import random
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix


# from imblearn.over_sampling import SMOTE
sns.set()

# %%
# data inladen hier

# parse time with seconds to general date
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
data = pd.read_csv('data.csv', parse_dates=['bookingdate'], date_parser=dateparse)
data['bookingdate'] = data['bookingdate'].dt.date
# print(data.head())
data.drop(['bookingdate'], axis=1);
# remove refused entries
data = data[data.simple_journal != 'Refused']

# distinguish datasets
data_benign = data[data.simple_journal == 'Settled']
data_fraud  = data[data.simple_journal == 'Chargeback']

print(data.columns)
data.head()

# sns.boxplot(x="simple_journal", y="amount", data=data)

# generates heatmap for issuer and shopper code

# data_fraud.head(100)
# Out:
# Index(['txid', 'bookingdate', 'issuercountrycode', 'txvariantcode', 'bin',
#        'amount', 'currencycode', 'shoppercountrycode', 'shopperinteraction',
#        'simple_journal', 'cardverificationcodesupplied', 'cvcresponsecode',
#        'creationdate', 'accountcode', 'mail_id', 'ip_id', 'card_id'],
#       dtype='object')
#     txid bookingdate issuercountrycode txvariantcode       bin    amount  \
# 0      1  2015-11-09                MX      mccredit  530056.0   64800.0
# 1      2  2015-11-09                MX      mccredit  547046.0   44900.0
# 2      3  2015-11-23                MX      mccredit  528843.0  149900.0
# 3      4  2015-11-23                MX      mccredit  547146.0  109900.0
# 4      5  2015-11-09                MX   visaclassic  477291.0   89900.0
# 5      6  2015-11-09                MX   visaclassic  493161.0   79900.0
# 6      7  2015-11-09                MX   visaclassic  477291.0   69900.0
# 7      8  2015-11-23                MX      mccredit  520416.0  129900.0
# 8      9  2015-12-08                MX   visaclassic  477291.0  129900.0
# 9     10  2015-11-09                MX      mccredit  549138.0   99900.0
# 10    11  2015-11-23                MX      mccredit  520416.0  129900.0
# 11    12  2015-11-09                MX       mcdebit  525678.0   84915.0
# 12    13  2015-12-08                MX      visagold  493173.0  119900.0
# 13    14  2015-11-09                MX      visagold  477213.0   99900.0
# 14    15  2015-11-23                MX      mccredit  520416.0  137900.0
# 15    16  2015-11-23                MX   visaclassic  455545.0  115300.0
# 16    17  2015-11-23                MX      mccredit  528843.0  102900.0
# 17    18  2015-11-23                MX   visaclassic  426807.0  159900.0
# 18    19  2015-12-08                MX      mccredit  544549.0   89165.0
# 19    20  2015-11-23                MX      mccredit  557910.0  119900.0
# 20    21  2015-11-23                MX      mccredit  520416.0  160800.0
# 21    22  2015-12-08                MX      mccredit  520021.0   89900.0
# 10          MXN                 MX          Ecommerce     Chargeback
# 11          MXN                 MX          Ecommerce     Chargeback
# 12          MXN                 MX          Ecommerce     Chargeback
# 13          MXN                 MX          Ecommerce     Chargeback
# 14          MXN                 MX          Ecommerce     Chargeback
# 15          MXN                 MX          Ecommerce     Chargeback
# 16          MXN                 MX          Ecommerce     Chargeback
# 17          MXN                 MX          Ecommerce     Chargeback
# 18          MXN                 MX          Ecommerce     Chargeback
# 19          MXN                 MX          Ecommerce     Chargeback
# 20          MXN                 MX          Ecommerce     Chargeback
# 21          MXN                 MX          Ecommerce     Chargeback
# 22          MXN                 MX          Ecommerce     Chargeback
# 23          MXN                 US          Ecommerce     Chargeback
# 24          MXN                 MX          Ecommerce     Chargeback
# 25          MXN                 MX          Ecommerce     Chargeback
# 26          MXN                 MX          Ecommerce     Chargeback
# 27          MXN                 MX          Ecommerce     Chargeback
# 28          MXN                 MX          Ecommerce     Chargeback
# 29          MXN                 MX          Ecommerce     Chargeback
# ..          ...                ...                ...            ...
# 70          MXN                 MX          Ecommerce     Chargeback
# 71          MXN                 MX          Ecommerce     Chargeback
# 72          MXN                 MX          Ecommerce     Chargeback
# 73          MXN                 MX          Ecommerce     Chargeback
# 74          MXN                 MX          Ecommerce     Chargeback
# 75          MXN                 MX          Ecommerce     Chargeback
# 76          MXN                 MX          Ecommerce     Chargeback
# 77          MXN                 MX          Ecommerce     Chargeback
# 78          MXN                 MX          Ecommerce     Chargeback
# 79          MXN                 MX          Ecommerce     Chargeback
# 80          MXN                 MX          Ecommerce     Chargeback
# 81          MXN                 MX          Ecommerce     Chargeback
# 82          MXN                 MX          Ecommerce     Chargeback
# 83          MXN                 MX          Ecommerce     Chargeback
# 84          MXN                 MX          Ecommerce     Chargeback
# 85          MXN                 MX          Ecommerce     Chargeback
# 86          MXN                 MX          Ecommerce     Chargeback
# 87          MXN                 MX          Ecommerce     Chargeback
# 88          MXN                 MX          Ecommerce     Chargeback
# 89          MXN                 MX          Ecommerce     Chargeback
# 90          MXN                 MX          Ecommerce     Chargeback
# 91          MXN                 MX          Ecommerce     Chargeback
# 92          MXN                 MX          Ecommerce     Chargeback
# 93          MXN                 MX          Ecommerce     Chargeback
# 94          MXN                 MX          Ecommerce     Chargeback
# 95          MXN                 MX          Ecommerce     Chargeback
# 96          MXN                 MX          Ecommerce     Chargeback
# 97          MXN                 MX          Ecommerce     Chargeback
# 98          MXN                 MX          Ecommerce     Chargeback
# 99          MXN                 MX          Ecommerce     Chargeback
#
#    cardverificationcodesupplied  cvcresponsecode         creationdate  \
# 0                          True                0  2015-07-01 23:03:11
# 1                          True                0  2015-07-02 04:50:55
# 2                          True                0  2015-07-02 14:30:28
# 3                          True                0  2015-07-03 07:53:37
# 4                          True                0  2015-07-08 18:35:35
# 5                          True                0  2015-07-08 23:04:26
# 6                          True                0  2015-07-09 02:31:36
# 7                          True                0  2015-07-09 04:56:48
# 8                          True                0  2015-07-09 22:55:40
# 13  MexicoAccount  email128862   ip70728  card250464
# 14  MexicoAccount  email205298   ip78514  card214147
# 15  MexicoAccount  email200329   ip85198   card67812
# 16  MexicoAccount   email52218   ip66658   card15137
# 17  MexicoAccount  email241832   ip77787   card31669
# 18  MexicoAccount  email171889   ip70519  card241186
# 19  MexicoAccount  email260026   ip65124  card157094
# 20  MexicoAccount  email105581   ip81624  card235670
# 21  MexicoAccount  email250381   ip64823   card43275
# 22  MexicoAccount   email13339   ip67976  card270780
# 23  MexicoAccount  email100813  ip352385  card236034
# 24  MexicoAccount   email21032   ip70585  card252061
# 25  MexicoAccount   email93270  ip112449  card147712
# 26  MexicoAccount   email21032   ip70585  card140567
# 27  MexicoAccount  email332232  ip112910  card148220
# 28  MexicoAccount  email136002  ip111250   card45886
# 29  MexicoAccount  email136002  ip111250   card45886
# ..            ...          ...       ...         ...
# 70  MexicoAccount   email85746   ip79980   card79066
# 71  MexicoAccount   email85714   ip84052  card195152
# 72  MexicoAccount   email85745   ip79997  card180625
# 73  MexicoAccount   email85684   ip84133  card185007
# 74  MexicoAccount  email125640   ip67696  card212019
# 75  MexicoAccount   email85716   ip79978   card88606
# 76  MexicoAccount  email343416   ip67927  card159223
# 77  MexicoAccount  email342107   ip69950  card221724
# 78  MexicoAccount  email343941   ip84116   card42364
# 79  MexicoAccount   email85707   ip84062  card255267
# 80  MexicoAccount  email268902   ip64814  card206924
# 81  MexicoAccount   email85715   ip84114    card3922
# 82  MexicoAccount  email143141   ip78380  card243564
# 83  MexicoAccount   email85708   ip84112  card225953
# 84  MexicoAccount  email342107   ip69950  card221724
# 85  MexicoAccount  email148527    ip6336  card108294
# 86  MexicoAccount   email26019   ip81756  card211757
# 87  MexicoAccount  email120246   ip84100  card100858
# 88  MexicoAccount  email120247   ip84105   card17736
# 89  MexicoAccount   email76886   ip82698   card75270
# 90  MexicoAccount  email269684  ip113860   card97365
# 91  MexicoAccount  email110710   ip79744  card136291
# 92  MexicoAccount  email110710   ip79744  card136291
# 93  MexicoAccount  email231311   ip84355    card7845
# 94  MexicoAccount  email265992   ip42080  card177780
# 95  MexicoAccount   email91755   ip68258  card135102
# 96  MexicoAccount   email51810  ip111247   card23089
# 97  MexicoAccount   email85705   ip81717  card227836
# 98  MexicoAccount  email288922   ip71405  card154659
# 99  MexicoAccount  email222155  ip111631  card174087
#
# [100 rows x 17 columns]

# %%
# Beetje data exploration hier
def generate_country_count(data):
    data_fraud = data[['issuercountrycode', 'shoppercountrycode']]
    data_grouped = data_fraud.groupby(['issuercountrycode', 'shoppercountrycode']).size().reset_index(name="count")
    pivot = data_grouped.pivot('issuercountrycode','shoppercountrycode').fillna(0)
    sns.heatmap(pivot, cmap="YlGnBu")

def generate_against_amount(data, col1, col2):
    data_fraud = data[[col1, col2, 'amount']]
    data_grouped = data_fraud.groupby([col1, col2])['amount'].agg('sum').reset_index(name='amount')
    pivot = data_grouped.pivot(index=col1, columns=col2, values='amount').fillna(0)
    sns.heatmap(pivot, cmap="YlGnBu")

# generate column against mean of amount
def generate_bar_mean(data, col):
    data_mean = data[[col, 'amount']].groupby([col])['amount'].agg('mean').reset_index(name='mean_amount')
    return data_mean

['txid', 'bookingdate', 'issuercountrycode', 'txvariantcode', 'bin',
       'amount', 'currencycode', 'shoppercountrycode', 'shopperinteraction',
       'simple_journal', 'cardverificationcodesupplied', 'cvcresponsecode',
       'creationdate', 'accountcode', 'mail_id', 'ip_id', 'card_id'] 
x= 'accountcode'
data_mean_fraud = generate_bar_mean(data_fraud, x)
data_mean_benign = generate_bar_mean(data_benign, x)
data_mean_fraud['type'] = 'fraud'
data_mean_benign['type']= 'benign'
# countries = data_mean_fraud[x].unique()
# data_mean_benign = data_mean_benign[data_mean_benign[x].isin(countries)]
data_mean = pd.concat([data_mean_benign, data_mean_fraud])
# data_mean.sort_values('shoppercountrycode')


plot = sns.barplot(x=x, y="mean_amount", hue="type", data=data_mean)

figure = plot.get_figure()    
figure.savefig('barchart_'+x+'.png', dpi=800)
# generate_against_amount(data_fraud, 'ip_id', 'card_id')

# generate_against_amount(data_benign, 'shoppercountrycode', 'cvcresponsecode')

# generate_country_count(data_benign)

# bin/cvcresponsecode 

# data_fraud.ip_id.value_counts()

# %%
data = data[['issuercountrycode', 'txvariantcode',
       'amount', 'currencycode', 'shoppercountrycode', 'shopperinteraction',
       'simple_journal', 'cardverificationcodesupplied', 'cvcresponsecode',
        'accountcode']]
categorical = ['issuercountrycode', 'txvariantcode',
       'currencycode', 'shoppercountrycode', 'shopperinteraction',
        'cardverificationcodesupplied', 'cvcresponsecode',
        'accountcode']
data_with_dummies = pd.get_dummies( data, columns =  categorical)
training_features, test_features, training_target, test_target, = train_test_split(data_with_dummies.drop(['simple_journal'], axis=1),
                                               data_with_dummies['simple_journal'],
                                               test_size = .1,
                                               random_state=12)



clf_rf = RandomForestClassifier(n_estimators=25, random_state=12)
clf_rf.fit(training_features, training_target)

res = clf_rf.predict(test_features)
# confusion_matrix(training_target, res)


pd.crosstab(res, test_target, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted   Chargeback  Settled    All
# True
# Chargeback           1       20     21
# Settled             27    23656  23683
# All                 28    23676  23704

# %%
# ax = sns.heatmap([data['currencycode'], data['shopperinteraction']], annot=True, fmt="d")
# data.currencycode.value_counts()
# data.shopperinteraction.value_counts()

df df == titanic.pivot_table( titanic.pivot_table(indexindex==''embark_townembark_town'', columnscolumns==''age_groupage_group'', valuesvalues==''farefare'', aggfuncaggfunc==np.median)np.median)
sns.heatmap(df, sns.heatmap(df, annotannot==TrueTrue, fmtfmt=="".1f.1f""))


sns.jointplot(data=data, x='amount', y='bin', kind='reg', color='g')
# Out:
#   File "<ipython-input-8-95cf3f205f61>", line 5
#     df df == titanic.pivot_table( titanic.pivot_table(indexindex==''embark_townembark_town'', columnscolumns==''age_groupage_group'', valuesvalues==''farefare'', aggfuncaggfunc==np.median)np.median)
#         ^
# SyntaxError: invalid syntax
